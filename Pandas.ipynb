# %% [markdown]
# <a href="https://colab.research.google.com/github/mwm26/Data-project/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PANDAS**
#
# Panda is a data analysis and data manipulation tool in Python.
# It's open source, built on top of the Python programming language.
#
# Used for data wrangling and data cleaning as well
#
# More powerful than Excel

# %%
# !pip install pandas

# %%
#shortcut so you don't have to type out the word 'pandas'
import pandas as pd

# %% [markdown]
# Series is a single column
#
# Dataframe  is a multidimentional table  made up of a collection of series (similar to a spreadsheet on excel)
#
# csv - comma separated values

# %%
data = 'https://raw.githubusercontent.com/gsusAguirreArz/2022-billionaire-EDA/master/out/2022_billionaires.csv'

# %%
forbes_df = pd.read_csv(data)

# %% [markdown]
# alternatively

# %%
forbes = pd.read_csv ('https://raw.githubusercontent.com/gsusAguirreArz/2022-billionaire-EDA/master/out/2022_billionaires.csv')

# %%
forbes
# Out:
#       Unnamed: 0   rank                       name   networth  age  \
# 0              0   Rank                       Name  Net Worth  Age
# 1              1     1.                 Elon Musk      $219 B   50
# 2              2     2.                Jeff Bezos      $171 B   58
# 3              3     3.  Bernard Arnault & family      $158 B   73
# 4              4     4.                Bill Gates      $129 B   66
# ...          ...    ...                        ...        ...  ...
# 2608        2608  2578.    Jorge Gallardo Ballart        $1 B   80
# 2609        2609  2578.              Nari Genomal        $1 B   82
# 2610        2610  2578.            Ramesh Genomal        $1 B   71
# 2611        2611  2578.            Sunder Genomal        $1 B   68
# 2612        2612  2578.     Horst-Otto Gerberding        $1 B   69
#
#                   country                  source           industry
# 0     Country / Territory                  Source           Industry
# ...

# %%
forbes_df
# Out:
#       Unnamed: 0   rank                       name   networth  age  \
# 0              0   Rank                       Name  Net Worth  Age
# 1              1     1.                 Elon Musk      $219 B   50
# 2              2     2.                Jeff Bezos      $171 B   58
# 3              3     3.  Bernard Arnault & family      $158 B   73
# 4              4     4.                Bill Gates      $129 B   66
# ...          ...    ...                        ...        ...  ...
# 2608        2608  2578.    Jorge Gallardo Ballart        $1 B   80
# 2609        2609  2578.              Nari Genomal        $1 B   82
# 2610        2610  2578.            Ramesh Genomal        $1 B   71
# 2611        2611  2578.            Sunder Genomal        $1 B   68
# 2612        2612  2578.     Horst-Otto Gerberding        $1 B   69
#
#                   country                  source           industry
# 0     Country / Territory                  Source           Industry
# ...

# %%
#gives you the first 5 rows of data. if you fill in the brackets with numbers-up to 50- it will call back those rows
forbes.head()

# %%
forbes.head(50)

# %%
#will call back the last 5 rows of data
forbes.tail()
# Out:
#       Unnamed: 0   rank                     name networth age      country  \
# 2608        2608  2578.  Jorge Gallardo Ballart      $1 B  80        Spain
# 2609        2609  2578.            Nari Genomal      $1 B  82  Philippines
# 2610        2610  2578.          Ramesh Genomal      $1 B  71  Philippines
# 2611        2611  2578.          Sunder Genomal      $1 B  68  Philippines
# 2612        2612  2578.   Horst-Otto Gerberding      $1 B  69      Germany
#
#                       source           industry
# 2608         pharmaceuticals        Healthcare
# 2609                 apparel  Fashion & Retail
# 2610                 apparel  Fashion & Retail
# 2611                garments  Fashion & Retail
# 2612  flavors and fragrances   Food & Beverage

# %%
forbes.tail(50)
# Out:
#       Unnamed: 0   rank                        name networth  age  \
# 2563        2563  2448.             Surin Upatkoon    $1.1 B   72
# 2564        2564  2448.              Sunil Vachani    $1.1 B   53
# 2565        2565  2448.                Murat Vargi    $1.1 B   74
# 2566        2566  2448.        Pongsak Viddayakorn    $1.1 B   88
# 2567        2567  2448.              Wang Linxiang    $1.1 B  NaN
# 2568        2568  2448.                Wang Shumin    $1.1 B   65
# 2569        2569  2448.              Richard Warke    $1.1 B  NaN
# 2570        2570  2448.           Anne Werninghaus    $1.1 B   36
# 2571        2571  2448.                 Allan Wong    $1.1 B   72
# 2572        2572  2448.                 Chaoqun Wu    $1.1 B   52
# 2573        2573  2448.                 Wu Yonghua    $1.1 B   51
# 2574        2574  2448.                Wu Zhenxing    $1.1 B   52
# 2575        2575  2448.         Franziska Wuerbser    $1.1 B   34
# ...

# %%
forbes.shape
#(rows, columns)
# Out:
# (2613, 8)

# %%
#info gives you a summary
#object is anything text- like.
forbes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2613 entries, 0 to 2612
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2613 non-null   int64
#  1   rank        2613 non-null   object
#  2   name        2613 non-null   object
#  3   networth    2613 non-null   object
#  4   age         2528 non-null   object
#  5   country     2613 non-null   object
#  6   source      2613 non-null   object
#  7   industry    2613 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 163.4+ KB

# %% [markdown]
# age and net-worth are classed as object instead of intergers. We need to clean this

# %%
#will give you descriptive statistics about a dataset that includes intergers
forbes.describe()

# %%
#when you specify by putting in the brackets, it can return other datatypes like object
#unique refers to the amount of things mentioned *think sumif
forbes.describe(include=['object'])
# Out:
#          rank  name networth   age        country       source  \
# count    2613  2613     2613  2528           2613         2613
# unique    229  2599      229    77             76          896
# top     1929.  Name   $1.5 B    58  United States  real estate
# freq      147    13      147    79            719          148
#
#                       industry
# count                     2613
# unique                      19
# top     Finance & Investments
# freq                       386

# %%
#not a permanent change
forbes.drop(columns = ['Unnamed: 0','rank'], axis='columns' )

# %%
forbes.drop(columns = ['Unnamed: 0','rank'])
# Out:
#                            name   networth  age              country  \
# 0                          Name  Net Worth  Age  Country / Territory
# 1                    Elon Musk      $219 B   50        United States
# 2                   Jeff Bezos      $171 B   58        United States
# 3     Bernard Arnault & family      $158 B   73               France
# 4                   Bill Gates      $129 B   66        United States
# ...                         ...        ...  ...                  ...
# 2608    Jorge Gallardo Ballart        $1 B   80                Spain
# 2609              Nari Genomal        $1 B   82          Philippines
# 2610            Ramesh Genomal        $1 B   71          Philippines
# 2611            Sunder Genomal        $1 B   68          Philippines
# 2612     Horst-Otto Gerberding        $1 B   69              Germany
#
#                       source           industry
# 0                     Source           Industry
# ...

# %%
#It will permanately delete what you have asked it to drop
forbes.drop(columns = ['Unnamed: 0','rank'], axis='columns',inplace=True )

# %%
#create another variable so you can edit what you want without changing the orignal source code
forbes_clean = forbes.drop (columns = ['source'], axis = 'columns')

# %%
forbes_clean
# Out:
#                            name   networth  age              country  \
# 0                          Name  Net Worth  Age  Country / Territory
# 1                    Elon Musk      $219 B   50        United States
# 2                   Jeff Bezos      $171 B   58        United States
# 3     Bernard Arnault & family      $158 B   73               France
# 4                   Bill Gates      $129 B   66        United States
# ...                         ...        ...  ...                  ...
# 2608    Jorge Gallardo Ballart        $1 B   80                Spain
# 2609              Nari Genomal        $1 B   82          Philippines
# 2610            Ramesh Genomal        $1 B   71          Philippines
# 2611            Sunder Genomal        $1 B   68          Philippines
# 2612     Horst-Otto Gerberding        $1 B   69              Germany
#
#                industry
# 0              Industry
# 1           Automotive
# 2           Technology
# 3     Fashion & Retail
# ...

# %% [markdown]
# How to create own DataFrame

# %%
my_dict = {'Student ID': [1,2,3,4,5],
           'Student Name': ['Anna', 'Victoria', 'Simi', 'Peace', 'Kam'],
           'Subject': ['Data', 'Data', 'Data', 'Data', 'Data']}

# %%
df_dict = pd.DataFrame(my_dict)

# %%
df_dict
# Out:
#    Student ID Student Name Subject
# 0           1         Anna    Data
# 1           2     Victoria    Data
# 2           3         Simi    Data
# 3           4        Peace    Data
# 4           5          Kam    Data
